# %%
import pandas as pd

# %%
rating = pd.read_csv('../ratings.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-083ce6b7bac6> in <module>
#       1 rating = pd.read_csv('../ratings.csv')
# ----> 2 tag = pd.read_csv('../rags.csv')
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
rating.tail(50)
# Out:
#           userId  movieId  rating   timestamp
# 27753394  283228     2300     4.0  1354137272
# 27753395  283228     2405     3.5  1354118843
# 27753396  283228     2420     3.5  1354159787
# 27753397  283228     2511     5.0  1379882745
# 27753398  283228     2571     5.0  1354137530
# 27753399  283228     2616     4.0  1354118846
# 27753400  283228     2688     3.5  1354118860
# 27753401  283228     2791     5.0  1379882953
# 27753402  283228     2872     4.5  1354118833
# 27753403  283228     2944     4.5  1354118819
# 27753404  283228     2948     4.5  1354159780
# 27753405  283228     3020     4.0  1354118850
# 27753406  283228     3033     2.5  1354159774
# 27753407  283228     3088     5.0  1354137193
# 27753408  283228     3096     4.5  1379882783
# 27753409  283228     3108     4.0  1354118773
# 27753410  283228     3114     4.5  1379882803
# 27753411  283228     3176     4.0  1354159768
# 27753412  283228     3257     3.0  1354159763
# ...

# %%
rating.groupby('userId').count()
# Out:
#         movieId  rating  timestamp
# userId
# 1            16      16         16
# 2            15      15         15
# 3            11      11         11
# 4           736     736        736
# 5            72      72         72
# ...         ...     ...        ...
# 283224      329     329        329
# 283225       20      20         20
# 283226       11      11         11
# 283227       17      17         17
# 283228      113     113        113
#
# [283228 rows x 3 columns]

# %%
tag = pd.read_csv('../tags.csv')
tag.head()
# Out:
#    userId  movieId           tag   timestamp
# 0      14      110          epic  1443148538
# 1      14      110      Medieval  1443148532
# 2      14      260        sci-fi  1442169410
# 3      14      260  space action  1442169421
# 4      14      318  imdb top 250  1442615195

# %%
rating.head(700)
# Out:
#      userId  movieId  rating   timestamp
# 0         1      307     3.5  1256677221
# 1         1      481     3.5  1256677456
# 2         1     1091     1.5  1256677471
# 3         1     1257     4.5  1256677460
# 4         1     1449     4.5  1256677264
# ..      ...      ...     ...         ...
# 695       4     7704     4.0  1127947061
# 696       4     7810     4.0  1113766720
# 697       4     7811     4.0  1123989697
# 698       4     7812     4.0  1145937567
# 699       4     7841     4.5  1113766661
#
# [700 rows x 4 columns]
